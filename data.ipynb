# %%
import pandas as pd

# %%
df= pd.read_csv("march_cleaned.csv")

# %%
df
# Out:
#                      Time  EacToday(kWh)  EacTotal(kWh)  Ppv(W)  \
# 0     2025-03-01 06:52:01            0.0       323720.4   405.7
# 1     2025-03-01 06:57:01            0.0       323720.4   106.4
# 2     2025-03-01 07:02:01            0.0       323720.4   106.8
# 3     2025-03-01 07:07:01            0.0       323720.4   418.7
# 4     2025-03-01 07:12:01            0.0       323720.4   752.1
# ...                   ...            ...            ...     ...
# 4627  2025-03-31 18:54:02          526.4       340025.0   154.1
# 4628  2025-03-31 18:59:02          526.5       340025.1    80.8
# 4629  2025-03-31 19:04:02          526.5       340025.1     2.7
# 4630  2025-03-31 19:09:02          526.5       340025.1     6.1
# 4631  2025-03-31 19:14:03          526.5       340025.1     0.0
#
#       EpvToday(kWh)  EpvTotal(kWh)  TimeTotal(S)  IacR(A)  IacS(A)  IacT(A)  \
# 0               0.0       632154.1    33110887.5      0.0      0.0      0.0
# ...

# %%
needed=df["AMTemp1(℃)"]
needed
# Out:
# 0       23.9
# 1       25.4
# 2       27.1
# 3       28.6
# 4       30.0
#         ...
# 4627    49.1
# 4628    49.7
# 4629    48.7
# 4630    47.9
# 4631    48.5
# Name: AMTemp1(℃), Length: 4632, dtype: float64

# %%
filtered = df[["AMTemp1(℃)","EacToday(kWh)"]]
filtered
# Out:
#       AMTemp1(℃)  EacToday(kWh)
# 0           23.9            0.0
# 1           25.4            0.0
# 2           27.1            0.0
# 3           28.6            0.0
# 4           30.0            0.0
# ...          ...            ...
# 4627        49.1          526.4
# 4628        49.7          526.5
# 4629        48.7          526.5
# 4630        47.9          526.5
# 4631        48.5          526.5
#
# [4632 rows x 2 columns]

# %%
filtered.to_csv("one_u_one_y.csv", index=False)
